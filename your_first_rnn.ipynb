# %% [markdown]
# # Your first Recurrent Neural Network (RNN)

# %% [markdown]
# 🙌 Welcome to RNNs! After using CNNs in the previous lesson to deal with images (spatial data), you are going to deal with time-related data (***temporal data***).
#
# 🎯 Goals of this warm-up challenge:
# 1. Understand what temporal data is
# 2. Build your first Recurrent Neural Networks

# %% [markdown]
# ## A Note on Google Colab

# %% [markdown]
# From now on, you no longer need to use Google Colab. There will be **no performance gains** from using it, as today's machines are powerful enough to tackle this challenge — especially if you're on a MacBook with an MX chip! 😉
#
# Proceed with the challenge as you normally would with Jupyter Notebook (❌ Do not use Colab ❌)
#
# Good luck! 🚀

# %% [markdown]
# ## (1) 📚 The dataset

# %% [markdown]
# _Disclaimer: nothing to code by yourself in this section, read it carefully and run the cells. We want you to focus on the RNN and LSTM models, not some Pythonesque questions_ 😉

# %% [markdown]
# 🔢 Imagine that we have access to some data about employees in a company.

# %%
import numpy as np

X = np.load('X.npy')
y = np.load('y.npy')

# %%
X.shape, y.shape
# Out:
# ((25000, 10, 3), (25000,))

# %% [markdown]
# ☝️ The dataset describes the evolution of the **employment status of 25 000 employees, year after year**: each sequence corresponds to 10 consecutive years, where each year describes a job situation, comprising 3 components
# - the salary,
# - the number of people under someone's responsibility,
# - the size of the company.
#
# 🕵🏻 To understand the dataset a bit better, let's look at the data of the first employee.

# %%
import pandas as pd

employee_0 = pd.DataFrame(X[0],
                          columns=['salary',
                                   'responsibility',
                                   'company_size'])
round(employee_0,2)
# Out:
#    salary  responsibility  company_size
# 0    0.80           10.73         102.0
# 1    0.50           10.73         102.0
# 2    0.60           10.73         102.0
# 3    0.71           10.73         130.0
# 4    0.94           10.73         130.0
# 5    1.05           10.73         130.0
# 6    1.12           32.00         108.0
# 7    4.87           32.00         108.0
# 8    4.97           33.00         108.0
# 9    5.20           39.00         108.0

# %% [markdown]
# 🎯 The goal in this challenge is to predict the montly salary on the 11th year for each of these 25,000 employees, based on the past observations.

# %%
# For example, the first employee earns 6.499 k USD per month
# during the 11th year at the company
y[0]
# Out:
# 6.499

# %% [markdown]
# 📈 To help you get a better understanding about the evolution of the salaries, the number of people under their responsibility and the company size over the years, you can run the cell down below. Can you visually detect some correlations between these three variables?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

number_of_employees = len(X)

### Choosing random employees
##### As the employees are selected randomly, feel free to re-run this cell a few times !

number_of_randomly_selected_employees = 5

random_selection = np.random.randint(0, 
                                     number_of_employees,
                                     number_of_randomly_selected_employees)


### Plotting data for the selected employees

plt.title('Salary')
for r in random_selection:
    plt.plot(X[r, :, 0],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('# People responsibile for')
for r in random_selection:
    plt.plot(X[r, :, 1],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('Company sizes')
for r in random_selection:
    plt.plot(X[r, :, 2],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# 🕵🏻 **Data Exploration** 🕵🏻 Look at the distribution of:
# * all the salaries during the 10th year,
# * people under someone's responsibility,
# * and the company sizes
#
# to get a better understanding of the variability of observations

# %%
import seaborn as sns

plt.title("Salaries on the 10th year")
sns.histplot(X[:, -1, 0].flatten()) # all the employees, last year, feature #0 = salaries
plt.show()

plt.title("# of people under someone's responsibility")
sns.histplot(X[:, :, 1].flatten()) # all the employees, all the years, feature #1 = responsabilities
plt.show()

plt.title("Company size")
sns.histplot(X[:, :, 2].flatten()) # all the employees, all the years, feature #2 = company size
plt.show()

# %% [markdown]
# ✂️ **Hold-out method** Let's split the dataset in a train and test set (80/20)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# Notice that we are train_test_splitting the 25 000 employees!

# %% [markdown]
# ## (2) 💻 A Simple RNN

# %% [markdown]
# 🤗 Now that you are familiar with this company's dataset, you will create your first Recurrent Neural Network. Let's start with a simple architecture.

# %% [markdown]
# ❓ **Question** ❓ Write a model that has:
# - a ***Normalization*** layer adapted to the training set
# - a ***SimpleRNN*** layer with 20 *units* (don't forget that `tanh` is better suited as an activation function for a Recurrent Layer)
# - a ***Dense*** layer with 10 neurons
# - a ***Dense*** layer specific to your task (= to ***predict*** a salary)
#
# 👩🏻‍🏫 <u>Remember</u>: You don't need to specify an `input_shape`: as soon as your Normalizer has been adapted to your train set, it has memorized the input shape!

# %%
# import simple

# %%
# RNN model with normalization layer to the training data, one RNN layer with 20 units and one Dense layer with 10 neurons and a dense prediction layer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, SimpleRNN, BatchNormalization
from tensorflow.keras.optimizers import Adam

model1 = Sequential()

model1.add(BatchNormalization(input_shape=(X_train.shape[1], X_train.shape[2])))

model1.add(SimpleRNN(20, activation='tanh',return_sequences=True))
#model.add(Dropout(0.2))
#model1.add(LSTM(20))
#model.add(Dropout(0.2))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(1, activation='linear'))

model1.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

model1.summary()

history = model1.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_split=0.2)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_4 (Batc  (None, 10, 3)            12
#  hNormalization)
#
#  simple_rnn (SimpleRNN)      (None, 10, 20)            480
#
#  dense_10 (Dense)            (None, 10, 10)            210
#
#  dense_11 (Dense)            (None, 10, 1)             11
#
# =================================================================
# Total params: 713
# Trainable params: 707
# Non-trainable params: 6
# _________________________________________________________________
# Epoch 1/50
# 500/500 [==============================] - 4s 6ms/step - loss: 36.5389 - val_loss: 33.3516
# Epoch 2/50
# 500/500 [==============================] - 3s 5ms/step - loss: 32.0427 - val_loss: 33.0086
# Epoch 3/50
# 500/500 [==============================] - 2s 5ms/step - loss: 31.7542 - val_loss: 32.7587
# Epoch 4/50
# 500/500 [==============================] - 2s 5ms/step - loss: 31.5989 - val_loss: 32.6110
# Epoch 5/50
# 500/500 [==============================] - 3s 5ms/step - loss: 31.5443 - val_loss: 32.5915
# Epoch 6/50
# 500/500 [==============================] - 3s 5ms/step - loss: 31.5115 - val_loss: 32.6337
# Epoch 7/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.5063 - val_loss: 32.5838
# Epoch 8/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.5002 - val_loss: 32.5848
# Epoch 9/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4883 - val_loss: 32.5602
# Epoch 10/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4889 - val_loss: 32.5497
# Epoch 11/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4839 - val_loss: 32.5728
# Epoch 12/50
# 500/500 [==============================] - 4s 7ms/step - loss: 31.4654 - val_loss: 32.5307
# Epoch 13/50
# 500/500 [==============================] - 4s 8ms/step - loss: 31.4816 - val_loss: 32.5268
# Epoch 14/50
# 500/500 [==============================] - 4s 8ms/step - loss: 31.4720 - val_loss: 32.5360
# Epoch 15/50
# 500/500 [==============================] - 4s 7ms/step - loss: 31.4671 - val_loss: 32.6292
# Epoch 16/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4728 - val_loss: 32.5159
# Epoch 17/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4670 - val_loss: 32.5244
# Epoch 18/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4797 - val_loss: 32.5260
# Epoch 19/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4631 - val_loss: 32.5540
# Epoch 20/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4720 - val_loss: 32.5260
# Epoch 21/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4653 - val_loss: 32.5178
# Epoch 22/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4645 - val_loss: 32.5487
# Epoch 23/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4674 - val_loss: 32.5830
# Epoch 24/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4695 - val_loss: 32.5746
# Epoch 25/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4634 - val_loss: 32.5545
# Epoch 26/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4576 - val_loss: 32.5294
# Epoch 27/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4375 - val_loss: 32.5285
# Epoch 28/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4571 - val_loss: 32.5745
# Epoch 29/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4589 - val_loss: 32.5263
# Epoch 30/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4649 - val_loss: 32.5885
# Epoch 31/50
# 500/500 [==============================] - 4s 7ms/step - loss: 31.4605 - val_loss: 32.5325
# Epoch 32/50
# 500/500 [==============================] - 4s 7ms/step - loss: 31.4538 - val_loss: 32.5196
# Epoch 33/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4679 - val_loss: 32.5822
# Epoch 34/50
# 500/500 [==============================] - 4s 8ms/step - loss: 31.4535 - val_loss: 32.5216
# Epoch 35/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4647 - val_loss: 32.5422
# Epoch 36/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4643 - val_loss: 32.5394
# Epoch 37/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4437 - val_loss: 32.5894
# Epoch 38/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4628 - val_loss: 32.5198
# Epoch 39/50
# 500/500 [==============================] - 4s 8ms/step - loss: 31.4509 - val_loss: 32.5443
# Epoch 40/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4465 - val_loss: 32.5555
# Epoch 41/50
# 500/500 [==============================] - 4s 8ms/step - loss: 31.4631 - val_loss: 32.5456
# Epoch 42/50
# 500/500 [==============================] - 4s 7ms/step - loss: 31.4421 - val_loss: 32.6675
# Epoch 43/50
# 500/500 [==============================] - 3s 6ms/step - loss: 31.4577 - val_loss: 32.5244
# Epoch 44/50
# 500/500 [==============================] - 4s 7ms/step - loss: 31.4500 - val_loss: 32.5142
# Epoch 45/50
# 500/500 [==============================] - 4s 7ms/step - loss: 31.4551 - val_loss: 32.5559
# Epoch 46/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4559 - val_loss: 32.5458
# Epoch 47/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4506 - val_loss: 32.5254
# Epoch 48/50
# 500/500 [==============================] - 3s 7ms/step - loss: 31.4573 - val_loss: 32.5194
# Epoch 49/50
# 500/500 [==============================] - 4s 7ms/step - loss: 31.4532 - val_loss: 32.5150
# Epoch 50/50
# 500/500 [==============================] - 4s 8ms/step - loss: 31.4641 - val_loss: 32.5225

# %%
from tensorflow.keras.layers import Normalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Flatten
# Out:
# 2022-11-17 10:53:49.720268: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-17 10:53:50.479518: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-17 10:53:50.479536: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-17 10:53:50.543381: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-17 10:53:52.033831: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-17 10:53:52.034056: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-17 10:53:52.034071: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# modify prediction layer to predict the salary on the 11th yea

# %% [markdown]
# ❓ **Question**: How many trainable parameters does your RNN have ❓

# %%
# how many trainables in this model?
model.count_params()
# Out:
# 5433

# %% [markdown]
# ❓ **Question** ❓ Try to recompute the number of parameters manually.

# %% [markdown]
# > YOUR ANSWER HERE

# %% [markdown]
# <details>
#     <summary><i>Answer</i></summary>
#
#
# - <u> Normalization Layer</u>:
#     - This layer has $\color{red}{n_x = 3} $ features (salary, responsibility, company size) to normalize. Each of them requires to compute the <font color=blue>_mean_</font>  and the <font color=blue>_standard_deviation_</font>. So we have $\color{red}{n_x = 3} \times \color{blue}{2} = 6$ non-trainable parameters. The 7th parameter is a bias initially set to 0.
#
# - <u> Recurrent Layer</u>:
#     - If $\color{green}{n_h = 20} $ RNN units are applied in parallel to $\color{red}{n_x = 3} $ features, then the Recurrent Layer has $\color{green}{n_h}(\color{green}{n_h} + \color{red}{n_x} + 1) = \color{green}{20} \times (\color{green}{20}+\color{red}{3}+1) = \color{green}{20} \times 24 = 480$ parameters to train.
#     - Notice how this number is *independent* of the length of each sequence (here 10 days)
#
# - <u> Dense Layer</u>:
#     - Starting with $\color{green}{n_h = 20} $ RNN units and $1$ bias, using 10 neurons, the Dense Layer has $ (\color{green}{20}+1) \times 10 = 21 \times 10 = 210$ parameters
#
# - <u> Predictive Dense Layer</u>:
#     - Starting with $10$ neurons and $1$ bias, using 1 neuron to predict the 11th salary, the Predictive Dense Layer has $ (10+1) \times 1 = 11 \times 1 = 11$ parameters
#
# </details>

# %% [markdown]
# ❓ **Question** ❓ Compile your model. For RNN, we recommend you to use the ***rmsprop*** optimizer (instead of *adam*).

# %%
# compile model with rmsprop optimizer
model1.compile(loss='mse', optimizer='rmsprop')

# %% [markdown]
# ❓ **Questions** ❓
#
# * Train your model on your training dataset:
#     * use a Validation Split of 20%
#     * and an Early Stopping Criterion with patience $= 5 $
# * Evaluate your performance on the test set

# %%
# train model on training data with validation split of 0.2 and patience of 5 epochs and return accuracy and loss
history = model1.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 9s 12ms/step - loss: 2.7604 - val_loss: 1.5373
# Epoch 2/50
# 500/500 [==============================] - 6s 12ms/step - loss: 2.7307 - val_loss: 1.4716
# Epoch 3/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.7997 - val_loss: 1.5056
# Epoch 4/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2.8629 - val_loss: 2.3723
# Epoch 5/50
# 500/500 [==============================] - 9s 17ms/step - loss: 2.7987 - val_loss: 1.2373
# Epoch 6/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2.8292 - val_loss: 1.7618
# Epoch 7/50
# 500/500 [==============================] - 8s 16ms/step - loss: 2.6846 - val_loss: 1.4970
# Epoch 8/50
# 500/500 [==============================] - 8s 16ms/step - loss: 2.8309 - val_loss: 1.3329
# Epoch 9/50
# 500/500 [==============================] - 8s 16ms/step - loss: 2.6927 - val_loss: 1.7654
# Epoch 10/50
# 500/500 [==============================] - 7s 14ms/step - loss: 2.6787 - val_loss: 1.4466
# Epoch 11/50
# 500/500 [==============================] - 9s 17ms/step - loss: 3.0492 - val_loss: 1.7116
# Epoch 12/50
# 500/500 [==============================] - 9s 19ms/step - loss: 2.6809 - val_loss: 1.3692
# Epoch 13/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.5903 - val_loss: 1.9071
# Epoch 14/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.7549 - val_loss: 1.2577
# Epoch 15/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.6747 - val_loss: 1.3205
# Epoch 16/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.7061 - val_loss: 1.3311
# Epoch 17/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.6127 - val_loss: 1.5853
# Epoch 18/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.4242 - val_loss: 1.2993
# Epoch 19/50
# 500/500 [==============================] - 11s 22ms/step - loss: 2.7812 - val_loss: 1.3828
# Epoch 20/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2.6836 - val_loss: 1.4915
# Epoch 21/50
# 500/500 [==============================] - 9s 17ms/step - loss: 2.4165 - val_loss: 1.3745
# Epoch 22/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.5532 - val_loss: 2.1359
# Epoch 23/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2.4843 - val_loss: 1.3065
# Epoch 24/50
# 500/500 [==============================] - 9s 17ms/step - loss: 2.3701 - val_loss: 1.2498
# Epoch 25/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2.6181 - val_loss: 1.4105
# Epoch 26/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.3557 - val_loss: 1.9510
# Epoch 27/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.7140 - val_loss: 1.3006
# Epoch 28/50
# 500/500 [==============================] - 10s 19ms/step - loss: 2.2918 - val_loss: 1.4696
# Epoch 29/50
# 500/500 [==============================] - 11s 23ms/step - loss: 2.4546 - val_loss: 1.3941
# Epoch 30/50
# 500/500 [==============================] - 8s 16ms/step - loss: 2.4955 - val_loss: 1.4844
# Epoch 31/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.4256 - val_loss: 2.2335
# Epoch 32/50
# 500/500 [==============================] - 7s 14ms/step - loss: 2.2342 - val_loss: 1.5507
# Epoch 33/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.4926 - val_loss: 1.7351
# Epoch 34/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.3054 - val_loss: 3.8194
# Epoch 35/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.4867 - val_loss: 1.5551
# Epoch 36/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2.2803 - val_loss: 1.4737
# Epoch 37/50
# 500/500 [==============================] - 9s 19ms/step - loss: 2.3817 - val_loss: 1.5054
# Epoch 38/50
# 500/500 [==============================] - 9s 19ms/step - loss: 2.2628 - val_loss: 2.3012
# Epoch 39/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2.3360 - val_loss: 1.6768
# Epoch 40/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.6058 - val_loss: 1.8436
# Epoch 41/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.3290 - val_loss: 1.6045
# Epoch 42/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.1775 - val_loss: 1.6425
# Epoch 43/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.5585 - val_loss: 2.0672
# Epoch 44/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.2859 - val_loss: 1.7175
# Epoch 45/50
# 500/500 [==============================] - 9s 17ms/step - loss: 2.2600 - val_loss: 1.2864
# Epoch 46/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.2015 - val_loss: 1.6089
# Epoch 47/50
# 500/500 [==============================] - 8s 16ms/step - loss: 2.3394 - val_loss: 1.6794
# Epoch 48/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.1167 - val_loss: 1.8929
# Epoch 49/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.2798 - val_loss: 2.1850
# Epoch 50/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.3689 - val_loss: 1.3968

# %% [markdown]
# ## (3) 💻 Baseline comparison

# %% [markdown]
# > ❗️ **Important reminder** ❗️
# >
# > ***Always remember to compare your Deep Learning models, and more generally any Machine Learning model, to a baseline model.***
#
# 🧑🏻‍🏫 Remember that our goal is to predict the salary of the employees for the 11th year. It is a ***Regression task***. What baseline could we build?
# 1. In the case of a traditional regression model, a baseline prediction for `y_test` is  to **predict the average of `y_train`**... but this option could be irrelevant for time-related series. Theoretically, someone's salary is supposed to increase over the years!
# 2. An alternative baseline prediction for a regression task is to **predict the last seen value**

# %%
# # Logistic regression as baseline to predict the last seen salary

# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score

# logreg = LogisticRegression(random_state=42)
# logreg.fit(X_train[:, -1, 0].reshape(-1, 1), y_train)
# y_pred = logreg.predict(X_test[:, -1, 0].reshape(-1, 1))
# print(f"Accuracy: {accuracy_score(y_pred, y_test)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [23], line 7
#       4 from sklearn.metrics import accuracy_score
#       6 logreg = LogisticRegression(random_state=42)
# ----> 7 logreg.fit(X_train[:, -1, 0].reshape(-1, 1), y_train)
#       8 y_pred = logreg.predict(X_test[:, -1, 0].reshape(-1, 1))
#       9 print(f"Accuracy: {accuracy_score(y_pred, y_test)}")
#
# File ~/.pyenv/versions/lewagon/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1146, in LogisticRegression.fit(self, X, y, sample_weight)
#    1136     _dtype = [np.float64, np.float32]
#    1138 X, y = self._validate_data(
#    1139     X,
#    1140     y,
#    (...)
#    1144     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1145 )
# -> 1146 check_classification_targets(y)
#    1147 self.classes_ = np.unique(y)
#    1149 multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#
# File ~/.pyenv/versions/lewagon/lib/python3.10/site-packages/sklearn/utils/multiclass.py:200, in check_classification_targets(y)
#     192 y_type = type_of_target(y, input_name="y")
#     193 if y_type not in [
#     194     "binary",
#     195     "multiclass",
#    (...)
#     198     "multilabel-sequences",
#     199 ]:
# --> 200     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %% [markdown]
# ❓ **Questions** ❓
# * Compute the Mean Absolute Error of a baseline model that predicts that the salary remains constant between the 10-th and 11-th year
# * Compare this baseline model to your RNN

# %%
# baseline model to predict if salary remains constant between years
# define model
model2 = Sequential()
model2.add(Flatten(input_shape=(X_train.shape[1], X_train.shape[2])))
model2.add(Dense(1, activation='linear'))
# compile model
model2.compile(loss='mse', optimizer='adam')
# train model
history2 = model2.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 1s 2ms/step - loss: 434.3612 - val_loss: 164.4643
# Epoch 2/50
# 500/500 [==============================] - 1s 2ms/step - loss: 111.7118 - val_loss: 66.9244
# Epoch 3/50
# 500/500 [==============================] - 1s 2ms/step - loss: 48.9221 - val_loss: 31.6903
# Epoch 4/50
# 500/500 [==============================] - 1s 2ms/step - loss: 24.3559 - val_loss: 15.9691
# Epoch 5/50
# 500/500 [==============================] - 1s 2ms/step - loss: 12.9220 - val_loss: 8.9197
# Epoch 6/50
# 500/500 [==============================] - 1s 2ms/step - loss: 7.2405 - val_loss: 5.2068
# Epoch 7/50
# 500/500 [==============================] - 1s 2ms/step - loss: 4.1183 - val_loss: 2.8220
# Epoch 8/50
# 500/500 [==============================] - 1s 3ms/step - loss: 2.4743 - val_loss: 1.9706
# Epoch 9/50
# 500/500 [==============================] - 1s 2ms/step - loss: 1.6059 - val_loss: 1.2643
# Epoch 10/50
# 500/500 [==============================] - 1s 2ms/step - loss: 1.2006 - val_loss: 1.0276
# Epoch 11/50
# 500/500 [==============================] - 1s 2ms/step - loss: 1.0891 - val_loss: 1.1144
# Epoch 12/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.9680 - val_loss: 0.8814
# Epoch 13/50
# 500/500 [==============================] - 1s 2ms/step - loss: 1.0110 - val_loss: 1.0670
# Epoch 14/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.9106 - val_loss: 0.7801
# Epoch 15/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.8841 - val_loss: 0.8317
# Epoch 16/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.9739 - val_loss: 0.7556
# Epoch 17/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.9034 - val_loss: 0.7223
# Epoch 18/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7941 - val_loss: 0.9463
# Epoch 19/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.8057 - val_loss: 1.1100
# Epoch 20/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.8187 - val_loss: 0.7052
# Epoch 21/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.8485 - val_loss: 0.6674
# Epoch 22/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.8077 - val_loss: 0.8295
# Epoch 23/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7313 - val_loss: 1.2488
# Epoch 24/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.8316 - val_loss: 1.5071
# Epoch 25/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.7914 - val_loss: 1.3442
# Epoch 26/50
# 500/500 [==============================] - 2s 4ms/step - loss: 0.8054 - val_loss: 0.6876
# Epoch 27/50
# 500/500 [==============================] - 2s 4ms/step - loss: 0.7953 - val_loss: 0.6651
# Epoch 28/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.8175 - val_loss: 0.6841
# Epoch 29/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.7249 - val_loss: 0.6685
# Epoch 30/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7868 - val_loss: 1.7590
# Epoch 31/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.8098 - val_loss: 0.6530
# Epoch 32/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7025 - val_loss: 0.6694
# Epoch 33/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7814 - val_loss: 0.7123
# Epoch 34/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7453 - val_loss: 0.6288
# Epoch 35/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7556 - val_loss: 0.7729
# Epoch 36/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7680 - val_loss: 0.6519
# Epoch 37/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7560 - val_loss: 0.6904
# Epoch 38/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7353 - val_loss: 0.6465
# Epoch 39/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7386 - val_loss: 0.8398
# Epoch 40/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7484 - val_loss: 0.6643
# Epoch 41/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7884 - val_loss: 0.7655
# Epoch 42/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7861 - val_loss: 0.7370
# Epoch 43/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7808 - val_loss: 0.6889
# Epoch 44/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7560 - val_loss: 0.9151
# Epoch 45/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.8194 - val_loss: 0.8019
# Epoch 46/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.6855 - val_loss: 0.6519
# Epoch 47/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7214 - val_loss: 2.9902
# Epoch 48/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7896 - val_loss: 1.1324
# Epoch 49/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.8417 - val_loss: 1.1353
# Epoch 50/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7884 - val_loss: 0.8737

# %%
# compare train and test loss
plt.plot(history2.history['loss'], label='train')
plt.plot(history2.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# compare model1 and model2
plt.plot(history.history['loss'], label='model1')
plt.plot(history2.history['loss'], label='model2')
plt.legend()
plt.show()

# %%
# compare model1 and model2 on test data
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)

plt.plot(y_pred1, label='model1')
plt.plot(y_pred2, label='model2')
#plt.plot(y_test, label='true')
plt.legend()
plt.show()
# Out:
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 0s 1ms/step

# %%
# model.predict of model1 to predict the salary on the 11th year
y_pred1 = model1.predict(X_test)
y_pred1
# Out:
# 157/157 [==============================] - 1s 4ms/step
# array([[ 2.0782952],
#        [ 8.246033 ],
#        [ 7.5929623],
#        ...,
#        [17.52484  ],
#        [14.873954 ],
#        [ 2.451995 ]], dtype=float32)

# %% [markdown]
# 👉 If you are stuck with this question, try `(4) LSTM` and come back to this afterwards.
#
# 🧑🏻‍🏫 Ask a TA if needed. Look at the answer only if you already tried to answer these questions unsuccessfully.
#
# <details>
#     <summary><i>Answer</i></summary>
#
#
# ```python
# def constant_prediction(X, y):
#     errors = []
#     for xx, yy in zip(X, y):
#         last_salary = xx[-1][0]        # Using the 10th salary to predict the 11th salary
#         errors.append(yy - last_salary)
#
#     return errors
# ```
#
# </details>

# %% [markdown]
# 😁 You should notice that your RNN performs a bit better than a baseline model.

# %% [markdown]
# ## (4) 💻 LSTM: Long-Short Term Memory

# %% [markdown]
# ❓ **Questions** ❓
#
# * Write the exact same model, but with a `LSTM` layer instead of a `SimpleRNN` layer
# * Evaluate your performance on the test set

# %%
# RNN model with normalization layer to the training data, one RNN layer with 20 units and one Dense layer with 10 neurons and a dense prediction layer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

model3 = Sequential()

model3.add(BatchNormalization(input_shape=(X_train.shape[1], X_train.shape[2])))

model3.add(LSTM(20, activation='tanh',return_sequences=True))
#model.add(Dropout(0.2))
model3.add(LSTM(20))
#model.add(Dropout(0.2))
model3.add(Dense(10, activation='relu'))
model3.add(Dense(1, activation='linear'))

model3.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

model3.summary()

history = model3.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_split=0.2)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_3 (Batc  (None, 10, 3)            12
#  hNormalization)
#
#  lstm_6 (LSTM)               (None, 10, 20)            1920
#
#  lstm_7 (LSTM)               (None, 20)                3280
#
#  dense_8 (Dense)             (None, 10)                210
#
#  dense_9 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 5,433
# Trainable params: 5,427
# Non-trainable params: 6
# _________________________________________________________________
# Epoch 1/50
# 500/500 [==============================] - 13s 19ms/step - loss: 20.9809 - val_loss: 7.7732
# Epoch 2/50
# 500/500 [==============================] - 7s 14ms/step - loss: 7.2431 - val_loss: 3.5019
# Epoch 3/50
# 500/500 [==============================] - 8s 15ms/step - loss: 5.9011 - val_loss: 2.6867
# Epoch 4/50
# 500/500 [==============================] - 7s 14ms/step - loss: 5.3364 - val_loss: 2.4056
# Epoch 5/50
# 500/500 [==============================] - 6s 13ms/step - loss: 4.9000 - val_loss: 4.0091
# Epoch 6/50
# 500/500 [==============================] - 7s 14ms/step - loss: 4.8323 - val_loss: 2.4219
# Epoch 7/50
# 500/500 [==============================] - 7s 15ms/step - loss: 4.9595 - val_loss: 1.8773
# Epoch 8/50
# 500/500 [==============================] - 7s 13ms/step - loss: 4.4891 - val_loss: 2.4131
# Epoch 9/50
# 500/500 [==============================] - 6s 13ms/step - loss: 4.4142 - val_loss: 1.8169
# Epoch 10/50
# 500/500 [==============================] - 7s 15ms/step - loss: 4.1686 - val_loss: 1.9718
# Epoch 11/50
# 500/500 [==============================] - 6s 13ms/step - loss: 4.2521 - val_loss: 1.5602
# Epoch 12/50
# 500/500 [==============================] - 7s 15ms/step - loss: 4.0276 - val_loss: 1.8047
# Epoch 13/50
# 500/500 [==============================] - 8s 15ms/step - loss: 4.2993 - val_loss: 1.7726
# Epoch 14/50
# 500/500 [==============================] - 8s 16ms/step - loss: 4.1836 - val_loss: 1.8331
# Epoch 15/50
# 500/500 [==============================] - 8s 15ms/step - loss: 3.9072 - val_loss: 2.0859
# Epoch 16/50
# 500/500 [==============================] - 7s 13ms/step - loss: 3.8415 - val_loss: 2.0994
# Epoch 17/50
# 500/500 [==============================] - 6s 13ms/step - loss: 3.9747 - val_loss: 1.6625
# Epoch 18/50
# 500/500 [==============================] - 6s 12ms/step - loss: 3.5029 - val_loss: 1.6925
# Epoch 19/50
# 500/500 [==============================] - 6s 12ms/step - loss: 3.7733 - val_loss: 1.8734
# Epoch 20/50
# 500/500 [==============================] - 6s 12ms/step - loss: 3.6825 - val_loss: 1.3345
# Epoch 21/50
# 500/500 [==============================] - 6s 12ms/step - loss: 3.5598 - val_loss: 1.4615
# Epoch 22/50
# 500/500 [==============================] - 9s 18ms/step - loss: 3.6066 - val_loss: 1.9984
# Epoch 23/50
# 500/500 [==============================] - 10s 19ms/step - loss: 3.4441 - val_loss: 1.7533
# Epoch 24/50
# 500/500 [==============================] - 10s 19ms/step - loss: 3.5315 - val_loss: 1.9908
# Epoch 25/50
# 500/500 [==============================] - 10s 19ms/step - loss: 3.2111 - val_loss: 1.9063
# Epoch 26/50
# 500/500 [==============================] - 8s 17ms/step - loss: 3.4956 - val_loss: 1.8515
# Epoch 27/50
# 500/500 [==============================] - 8s 16ms/step - loss: 3.2797 - val_loss: 2.3057
# Epoch 28/50
# 500/500 [==============================] - 7s 14ms/step - loss: 3.5370 - val_loss: 1.9113
# Epoch 29/50
# 500/500 [==============================] - 7s 15ms/step - loss: 3.2417 - val_loss: 1.9887
# Epoch 30/50
# 500/500 [==============================] - 8s 17ms/step - loss: 3.4237 - val_loss: 1.6110
# Epoch 31/50
# 500/500 [==============================] - 9s 19ms/step - loss: 3.3117 - val_loss: 1.7422
# Epoch 32/50
# 500/500 [==============================] - 9s 18ms/step - loss: 3.4301 - val_loss: 1.3666
# Epoch 33/50
# 500/500 [==============================] - 8s 16ms/step - loss: 3.3655 - val_loss: 1.7690
# Epoch 34/50
# 500/500 [==============================] - 7s 14ms/step - loss: 3.0276 - val_loss: 2.0199
# Epoch 35/50
# 500/500 [==============================] - 7s 14ms/step - loss: 3.4384 - val_loss: 1.6554
# Epoch 36/50
# 500/500 [==============================] - 8s 16ms/step - loss: 3.4404 - val_loss: 1.9849
# Epoch 37/50
# 500/500 [==============================] - 9s 18ms/step - loss: 3.2046 - val_loss: 1.6616
# Epoch 38/50
# 500/500 [==============================] - 8s 16ms/step - loss: 2.9836 - val_loss: 1.6555
# Epoch 39/50
# 500/500 [==============================] - 9s 17ms/step - loss: 2.8997 - val_loss: 1.5339
# Epoch 40/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2.8137 - val_loss: 1.5270
# Epoch 41/50
# 500/500 [==============================] - 11s 23ms/step - loss: 2.9100 - val_loss: 2.0020
# Epoch 42/50
# 500/500 [==============================] - 10s 20ms/step - loss: 2.8392 - val_loss: 1.5177
# Epoch 43/50
# 500/500 [==============================] - 8s 16ms/step - loss: 2.8106 - val_loss: 1.5645
# Epoch 44/50
# 500/500 [==============================] - 11s 22ms/step - loss: 3.0295 - val_loss: 1.5826
# Epoch 45/50
# 500/500 [==============================] - 8s 17ms/step - loss: 2.6854 - val_loss: 1.3455
# Epoch 46/50
# 500/500 [==============================] - 12s 23ms/step - loss: 2.6300 - val_loss: 1.6730
# Epoch 47/50
# 500/500 [==============================] - 11s 22ms/step - loss: 2.8476 - val_loss: 1.7211
# Epoch 48/50
# 500/500 [==============================] - 9s 17ms/step - loss: 2.7473 - val_loss: 1.4455
# Epoch 49/50
# 500/500 [==============================] - 10s 19ms/step - loss: 2.6448 - val_loss: 1.5105
# Epoch 50/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2.7228 - val_loss: 2.1217

# %% [markdown]
# 💪 The LSTM should perform a bit better than the SimpleRNN with a lower MAE.

# %% [markdown]
# 🏁 Congratulations! You know how to train a RNN on sequential data.
#
#
# 💾 Do not forget to git add/commit/push your notebook...
#
# 🚀 ... and move to the next challenge!
#
# ---
#
# <u>Note</u>: The sequences you worked with are totally fake. In case, you need to train and reproduce similar data, you can find below the functions that have been used to simulate such a dataset.

# %% [markdown]
# ## 🛠 (Utils)

# %%
def create_sequences(number):
    X, y = [], []
    
    for i in range(number):
        x_i, y_i = create_individual_sequence(10)
        X.append(x_i)
        y.append(y_i)
        
    return np.array(X), np.array(y)
            
def create_individual_sequence(length):
    company_sizes = []
    nb_persons = []
    salaries = []
    
    
    # Education level
    educ_level = [max(0, int(np.random.normal(10, 2)))]*length
    
    # Company size
    current_size = int(1 + np.random.beta(.4, 4)*500)
    for i in range(length):
        if not np.random.randint(4): # Change 1 out of 3 possibilities 
            current_size = int(max(1, np.random.normal(current_size, 50)))
        company_sizes.append(current_size)
    
    # Number of persons
    nb_iter = np.random.beta(.15, 4)*300
    for i in range(length):
        if not np.random.randint(2): # Change 1 out of 2 possibilities
            R_1 = np.random.beta(0.5, 8)*3
            nb_iter = nb_iter + max(-2, R_1*company_sizes[i] + np.random.randint(-2, 2))
            nb_iter = max(0, nb_iter)
            nb_iter = int(min(company_sizes[i]-1, nb_iter))
        nb_persons.append(nb_iter)
        
    
    # Salary
    salary_iter = max(800, int(np.random.normal(1200, 300)+ 0.05*company_sizes[0] +  np.random.normal(40, 400)))
    salaries.append(salary_iter)
    for i in range(1, length + 1):
        R_1 = np.random.normal(100, 50)
        change_person = nb_persons[i-1] - nb_persons[i-2]
        change_company = max(0, company_sizes[i-1] - company_sizes[i-2])
        salary_iter = salary_iter + 0.05*change_company + change_person*R_1 + np.random.normal(100, 50)
        salary_iter = max(int(salary_iter), 500)
        
        salaries.append(salary_iter)

    y = salaries[-1]/1000
    salaries = [_/1000 for _ in salaries[:-1]]
    
    return np.array([salaries, nb_persons, company_sizes]).T, y

# %%
#X, y = create_sequences(25000)

#np.save('X', X.astype(np.float32))
#np.save('y', y)
